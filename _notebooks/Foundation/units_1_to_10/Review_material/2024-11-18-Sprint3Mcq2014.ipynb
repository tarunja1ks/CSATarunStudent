# %% [markdown]
# ---
# layout: post
# title:  Wrong Answers 2014 mcq
# description: The 2014 mcq wrong answer review
# permalink: /csa/WrongAnswers2014mcq
# menu: nav/CSA_Units/csa_unitsummary.html
# ---

# %% [markdown]
# ## Topics most missed reason(26/40)
# - Making silly mistakes
# - Not reading fully the answer choice and skimming
# - Not reading the question fully and again skimming

# %% [markdown]
# Wrong Answered Questions
#
# Question 4
# ![Screenshot 2024-11-18 at 3 57 11 PM](https://github.com/user-attachments/assets/2ef29af7-e83a-4113-a041-33f8b2640f0b)
# Correct Answer: C
# Reason: I was being careless and forgot that both variables are integers so when you divide them it will stay an Integer. Next time I will read more carefully since this is a completely avoidable mistake.
#
#
# Question 8
# ![Screenshot 2024-11-18 at 3 58 40 PM](https://github.com/user-attachments/assets/74a4d823-2a68-4459-8cc3-abfd632aae91)
# Correct Answer: B
# Reason: I was again being careless and misread the code forgetting about the constructor with no parameters required.
#
#
# Question 10
# ![Screenshot 2024-11-18 at 4 00 49 PM](https://github.com/user-attachments/assets/49b0b84b-5184-4605-9635-d53266d70fb6)
# Correct Answer: B
# Reason: I was a bit silly here since I forgot how if there is no target within data and we try searching for it it will never be found and it will be a stack overflow error likely.
#
# Question 12
# ![Screenshot 2024-11-18 at 4 04 05 PM](https://github.com/user-attachments/assets/865654df-5ec3-4c1d-88ad-06afdfe5e50d)
# Correct Answer: C
# Reason: I again misread the code and forgot to see the index of 1 which was the starting value of the for loop.
#
# Question 15
# ![Screenshot 2024-11-18 at 4 05 00 PM](https://github.com/user-attachments/assets/0a7ad60b-2e04-4e3a-bec4-c9856fa638c9)
# Correct Answer: A
# Reason: I again was being not very intelligent when I misread the last possible or end bound value for the index in the forloop as it does k+1 which will throw an out-of-bounds error for option 2.
#
# Question 16
# ![Screenshot 2024-11-18 at 4 16 03 PM](https://github.com/user-attachments/assets/2cbc6b80-7c90-429e-add7-3332f9fc347f)
# Correct Answer: C
# Reason: I was again being a bit silly since I forgot that the -1 of that index will make it the end of the first part and mess up the combined array.
#
# Question 19
# ![Screenshot 2024-11-18 at 4 18 50 PM](https://github.com/user-attachments/assets/fc6f3ddd-eda4-480a-891a-c03bf9e17900)
# Correct Answer: D
# Reason: I had misread the answer choice since there is an or operator in between the 2 conditions so I should definitely reading better.
#
# Question 21
# ![Screenshot 2024-11-18 at 4 20 48 PM](https://github.com/user-attachments/assets/1a888746-4a82-497e-ab5a-0147f81d6b7b)
# Correct Answer:B
# Reason: I again was being very rushed/misreading the answer choice and forgot that it said minDiff not value which is what we want.
#
#
# Question 23
# ![Screenshot 2024-11-18 at 4 28 27 PM](https://github.com/user-attachments/assets/3255b2ee-68cf-40a4-a63b-c8da998048d9)
# Correct Answer: B
# Reason: This one was actually a bit tricky but I believe it is because it still adds it to the end of the list.
#
# Question 24
#
# ![Screenshot 2024-11-18 at 4 32 42 PM](https://github.com/user-attachments/assets/97ef3e6b-cb50-48eb-baae-13514a070652)
# Correct Answer: D
# Reason: I got the correct new Array but for some reason though of it as 2,0 as the index we want and swapped it accidentally.
#
# Question 30
# ![Screenshot 2024-11-18 at 4 35 24 PM](https://github.com/user-attachments/assets/335bb1b3-71ef-4144-8e36-fcdb0fba81fa)
# Correct Answer: C
# Reason: I misread again and forgot the +1 at the beginning of the first subtring.
#
# Question 31
# ![Screenshot 2024-11-18 at 4 37 00 PM](https://github.com/user-attachments/assets/42f03f36-6f25-4ddf-ae95-7c951606d360)
# Correct Answer: C
# Reason: I completely ignored the mystery function being called and rushed to click the answer where the array was unchanged.
#
# Question 34
# ![Screenshot 2024-11-18 at 4 40 36 PM](https://github.com/user-attachments/assets/be6de8ca-f7e3-4940-b7bc-abf85f1f8744)
# Correct Answer: B
# Reason: I forgot that the variables X and Y in the point class are private and need the setter methods being called to update them, which is again a super silly mistake.
#
# Question 40
# ![Screenshot 2024-11-18 at 4 50 01 PM](https://github.com/user-attachments/assets/ce5a7e3e-5212-4129-be1b-4d99832973b3)
# Correct Answer: C
# Reason: I forgot that recursion would cause it to print the result at the child most recursive call first and then backtrack to the first call to print it out.
